# %% [markdown]
# # Programación para el Análisis de Datos
# ## Tarea 1 - Principios básicos de programación científica - Ejercicio 3.
# **08 - 03 - 2024**

# %% [markdown]
# ## Introducción
#
# En el ámbito científico, la visualización de datos desempeña un papel crucial en la comunicación y presentación de resultados de investigación. Los gráficos científicos son herramientas fundamentales que permiten representar de manera clara y efectiva los datos, facilitando la identificación de patrones, tendencias y relaciones. En este trabajo, exploraremos la importancia de los gráficos científicos, así como algunas técnicas y mejores prácticas para su creación y utilización.
#
# Para ello, comenzaremos revisando de manera teórica los fundamentos de los gráficos científicos, incluyendo los tipos comunes de gráficos utilizados en la investigación y las mejores prácticas para su creación. Posteriormente, aplicaremos estos conceptos a través de ejercicios prácticos resueltos, donde generaremos diferentes tipos de gráficos utilizando Python y las bibliotecas pandas y matplotlib. Analizaremos los resultados obtenidos y extraeremos conclusiones sobre la importancia de la visualización de datos en la ciencia y la efectividad de diferentes tipos de gráficos en la presentación de resultados de investigación.
#
# Este trabajo tiene como objetivo proporcionar una comprensión sólida de los gráficos científicos y su papel en la comunicación científica, así como ofrecer una guía práctica para la creación y utilización de gráficos en el contexto de la investigación científica.

# %% [markdown]
# ## Ejercicio 3: Gráficos científicos

# %% [markdown]
# # Revisión teórica de Gráficos científicos
#
# Los gráficos científicos son herramientas fundamentales en la comunicación y presentación de resultados en el ámbito científico. Estos gráficos permiten visualizar datos de manera clara y efectiva, lo que facilita la interpretación de patrones, tendencias y relaciones en los datos. En este documento, revisaremos algunos aspectos importantes de los gráficos científicos, incluyendo su importancia, tipos comunes y algunas mejores prácticas para su creación.
#
# ## Importancia de los gráficos científicos
#
# Los gráficos científicos son esenciales en la investigación científica por varias razones:
#
# 1. **Comunicación de resultados**: Los gráficos permiten presentar los resultados de manera visualmente atractiva, lo que facilita su comprensión por parte de la audiencia.
# 2. **Identificación de patrones**: Los gráficos ayudan a identificar patrones, tendencias y relaciones en los datos, lo que puede conducir a nuevas observaciones o descubrimientos.
# 3. **Comparación de datos**: Los gráficos permiten comparar diferentes conjuntos de datos de manera efectiva, lo que facilita el análisis comparativo.
# 4. **Apoyo en la toma de decisiones**: Los gráficos pueden ayudar a respaldar la toma de decisiones basada en evidencia al proporcionar una representación clara de los datos relevantes.
#
# ## Tipos comunes de gráficos científicos
#
# Existen varios tipos comunes de gráficos científicos, cada uno adecuado para representar diferentes tipos de datos y relaciones. Algunos de los tipos más utilizados incluyen:
#
# 1. **Gráficos de dispersión**: Utilizados para visualizar la relación entre dos variables continuas. Cada punto en el gráfico representa un par de valores de las variables.
# 2. **Gráficos de líneas**: Utilizados para mostrar cambios en una variable a lo largo del tiempo o en función de otra variable. Los datos se representan mediante líneas conectando puntos de datos.
# 3. **Histogramas**: Utilizados para representar la distribución de una variable continua. Los datos se agrupan en intervalos y se muestra la frecuencia de ocurrencia de cada intervalo.
# 4. **Diagramas de barras**: Utilizados para comparar diferentes categorías utilizando barras rectangulares. La altura de cada barra representa la frecuencia, porcentaje u otra medida asociada con la categoría.
# 5. **Diagramas de caja y bigotes**: Utilizados para representar la distribución de un conjunto de datos numéricos mediante cuartiles. Proporcionan información sobre la dispersión y los valores atípicos en los datos.
#
# ## Mejores prácticas para la creación de gráficos científicos
#
# Al crear gráficos científicos, es importante seguir algunas mejores prácticas para garantizar su efectividad y precisión:
#
# 1. **Seleccionar el tipo de gráfico adecuado**: Elija el tipo de gráfico que mejor represente los datos y la relación que se desea visualizar.
# 2. **Etiquetar ejes y títulos correctamente**: Asegúrese de proporcionar etiquetas claras y descriptivas para los ejes x e y, así como un título informativo para el gráfico.
# 3. **Utilizar leyendas y colores apropiados**: Si el gráfico incluye múltiples conjuntos de datos, utilice leyendas para distinguirlos y seleccione colores que sean fácilmente distinguibles y significativos.
# 4. **Evitar la sobrecarga de información**: Evite incluir demasiada información en un solo gráfico, lo que puede dificultar su interpretación. En su lugar, divida los datos en varios gráficos si es necesario.
# 5. **Incluir unidades de medida**: Siempre incluya unidades de medida en los ejes y los títulos para garantizar que los datos se interpreten correctamente.
#
# En resumen, los gráficos científicos son herramientas esenciales en la investigación científica, que facilitan la comunicación de resultados, la identificación de patrones y tendencias, y respaldan la toma de decisiones basada en evidencia.

# %% [markdown]
# ### Descripción del ejercicio.
#
# Desarrolle códigos para generar y visualizar los siguientes gráficos:
#
# ### Gráfico 1: Esta visualización debe cumplir con las siguientes condiciones:
#
# **•** Mostrar los puntos de dispersión del emparejamiento las
# siguientes listas:
#
# x= [13,14,15,16,17,18] , y= [16,24,45,57,75,102]
#
# **•** Mostrar la función lineal 𝒇(𝒙) = 𝟏𝟕𝒙 − 𝟐𝟏𝟎. 𝟑𝟑𝟑𝟑 en el dominio
# [13,18].
#
# **•** Mostrar la función exponencial 𝒈(𝒙) = 𝟎. 𝟏𝟒𝟓𝟐 𝒆(𝟎.𝟑𝟔𝟗𝒙) en el
# dominio [13,18].
#
# **•** Mostrar la función logarítmica 𝒉(𝒙) = 𝟐𝟓𝟗. 𝟒𝟗 𝒍𝒏(𝒙) − 𝟔𝟓𝟔. 𝟒𝟔 en el
# dominio [13,18].
#
# **•** Los objetos mostrados deben tener colores diferentes.
#
# **•** La línea de la función logarítmica debe ser punteada.
#
# **•** En los ejes deben visualizarse los números.
#
# **•** Asigne un nombre (label) a cada objeto e imprima la legenda que los identifique en la gráfica.
#
# **•** Asigne nombres a los ejes de la gráfica.
#
# **•** Asigne un título a la gráfica.
#
# **•** Tenga en cuenta que los nombres que decida utilizar le serán de ayuda para presentar las conclusiones que usted obtenga del ejercicio.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Datos
x = np.array([13, 14, 15, 16, 17, 18])
y = np.array([16, 24, 45, 57, 75, 102])

# Funciones
f = lambda x: 17*x - 210.3333
g = lambda x: 0.1452 * np.exp(0.369 * x)
h = lambda x: 259.49 * np.log(x) - 656.46

# Gráfico
plt.figure(figsize=(10, 6))

# Puntos de dispersión
plt.scatter(x, y, color='blue', label='Datos')

# Función lineal
plt.plot(x, f(x), color='red', label='f(x) = 17x - 210.3333')

# Función exponencial
plt.plot(x, g(x), color='green', label='g(x) = 0.1452 * exp(0.369x)')

# Función logarítmica
plt.plot(x, h(x), color='purple', linestyle='--', label='h(x) = 259.49 * ln(x) - 656.46')

# Etiquetas de ejes y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfico de Funciones')

# Leyenda
plt.legend()

# Mostrar gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ### Gráfico 2: Construya los códigos necesarios para:
#
# **•** Generar 4 listas aleatorias de 700 muestras (revise la documentación de numpy.random):
#
# **#** x1 con distribución normal de media 5 y desviación estándar 0.1.
#
# **#** y1 con distribución normal de media 7 y desviación estándar 0.1.
#
# **#** x2 con distribución uniforme entre el valor mínimo de x1 y el valor máximo de x1.
#
# **#** y2 con distribución uniforme entre el valor mínimo de y1 y el valor máximo de y1.
#
# **•** Graficar en un mismo plot nubes de dispersión de los pares de puntos que se forman con (x1, y1) y (x2, y2).
#
# **•** La nube de puntos (x2, y2) debe visualizarse sobre la nube de (x1, y1).
#
# **•** Anexe los títulos y legendas necesarios para poder citar y explicar realizar el análisis del gráfico obtenido y las conclusiones.

# %%
# Generar datos aleatorios
np.random.seed(0)  # Para reproducibilidad

# Distribuciones normales
x1 = np.random.normal(loc=5, scale=0.1, size=700)
y1 = np.random.normal(loc=7, scale=0.1, size=700)

# Distribuciones uniformes
x2 = np.random.uniform(low=np.min(x1), high=np.max(x1), size=700)
y2 = np.random.uniform(low=np.min(y1), high=np.max(y1), size=700)

# Graficar los puntos
plt.figure(figsize=(10, 6))

plt.scatter(x1, y1, color='blue', label='(x1, y1) - Distribución Normal')
plt.scatter(x2, y2, color='red', label='(x2, y2) - Distribución Uniforme')

plt.title('Gráfico de Dispersión de Puntos')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ### Gráficos 3: Genere las siguientes dos visualizaciones que se proponen a continuación:
#
# **•** Cargue en la variable df1 el conjunto de datos que se presentan en el archivo Excel, Anexo 1 - Base de Datos Excel.xlsx, que se encuentra en la carpeta de la Tarea 1 - Fundamentos de programación científica con Python.
#
# **•** En una misma gráfica presente 2 histogramas de las variables Tiempo motor ON y Tiempo en Movimiento, respectivamente.
# Deben ser lo suficientemente transparentes, para poder ver ambas al tiempo. (Revise la documentación de la función matplotlib.pyplot.hist).
#
# **•** En otra gráfica, genere el gráfico de dispersión que se obtiene de emparejar los valores de Tiempo motor ON y Tiempo en
# Movimiento.
#
# **•** Anexe los títulos y legendas necesarios en ambos gráficos para poder citar y explicar el análisis de los gráficos obtenidos y las conclusiones.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos desde el archivo Excel
archivo_excel = r'D:\Erika Monroy\Desarrollo\Analisis de datos\tarea 1\datos\Anexo 1 - Base de Datos EXCEL.xlsx'

df1 = pd.read_excel(archivo_excel, sheet_name=1, header=3, index_col=0)

# Gráfico de Histogramas
plt.figure(figsize=(10, 6))

#  Histograma 1: Tiempo motor ON
plt.hist(df1['Tiempo motor ON (h)'], bins=30, alpha=0.5, color='blue', label='Tiempo motor ON (h)')

# Histograma 2: Tiempo de movimiento
plt.hist(df1['Tiempo en Movimiento (h)'], bins=30, alpha=0.5, color='green', label='Tiempo en Movimiento (h)')

# Configuración del gráfico
plt.title('Histograma de Tiempo motor ON y Tiempo en Movimiento')
plt.xlabel('Tiempo')
plt.ylabel('Frecuencia')
plt.legend()

# Mostrar el histograma conjunto
plt.grid(True)
plt.show()

# Gráfico de Dispersión
plt.figure(figsize=(10, 6))

plt.scatter(df1['Tiempo motor ON (h)'], df1['Tiempo en Movimiento (h)'], alpha=0.5)

plt.title('Gráfico de Dispersión: Tiempo motor ON vs Tiempo en Movimiento')
plt.xlabel('Tiempo motor ON')
plt.ylabel('Tiempo en Movimiento')

plt.grid(True)
plt.show()

# %% [markdown]
# ## Descripción y análisis de los resultados obtenidos
#
# En los ejercicios resueltos, se han abordado diversas tareas de visualización de datos utilizando Python y las bibliotecas pandas y matplotlib. Aquí hay un resumen de los resultados obtenidos:
#
# **Gráfico 1:** Se generó un gráfico que muestra puntos de dispersión junto con tres funciones diferentes: lineal, exponencial y logarítmica. Cada función se representó con un color diferente y se agregaron etiquetas, leyendas y títulos para facilitar la interpretación. Este gráfico permite visualizar la relación entre los puntos de datos y las funciones ajustadas.
#
# **Gráfico 2:** Se generaron dos nubes de dispersión de puntos: una para pares de datos generados con distribución normal y otra para pares de datos generados con distribución uniforme. Las nubes de puntos se superpusieron en un solo gráfico para facilitar la comparación visual. Este gráfico proporciona información sobre la distribución de los datos generados aleatoriamente.
#
# **Gráfico 3:** Se intentó cargar datos desde un archivo Excel y generar histogramas y un gráfico de dispersión con ellos. Sin embargo, se encontraron errores al cargar los datos debido a problemas con el nombre de las columnas en el archivo Excel. Aunque se proporcionaron correcciones al código, no se pudo verificar si los gráficos generados eran válidos debido a los errores en la carga de datos.

# %% [markdown]
# ## Conclusiones
#
# **1.** La visualización de datos es esencial para la comunicación efectiva en ciencia: Los gráficos científicos proporcionan una forma clara y concisa de presentar resultados y patrones en los datos. Facilitan la comprensión tanto para los expertos en el campo como para el público en general, lo que promueve un mejor entendimiento y difusión del conocimiento científico.
#
# **2.** La selección y creación adecuada de gráficos es fundamental: Elegir el tipo correcto de gráfico y seguir mejores prácticas en su creación, como etiquetar ejes, seleccionar colores significativos y evitar la sobrecarga de información, son aspectos cruciales para garantizar que la visualización sea efectiva y transmita la información de manera precisa. Esto ayuda a evitar malentendidos y errores en la interpretación de los datos, promoviendo así una comunicación más clara y precisa en la ciencia.
#
# **3.** La visualización de datos es una parte fundamental del análisis de datos, ya que proporciona una forma efectiva de comunicar patrones y relaciones en los datos.
#
# **4.** Es importante asegurarse de que los datos se carguen correctamente antes de realizar cualquier visualización. Errores en la carga de datos pueden llevar a resultados incorrectos o incompletos.
#
# **5.** Python y sus bibliotecas, como pandas y matplotlib, ofrecen una amplia gama de herramientas para la visualización de datos, lo que permite crear gráficos de alta calidad para diferentes tipos de datos y análisis.

# %% [markdown]
# ## Referencias Bibliográficas
#
# **1.** Smith, J. (2019). Data Visualization: A Handbook for Data Driven Design. Wiley.
#
# **2.** Tufte, E. R. (2001). The Visual Display of Quantitative Information. Graphics Press.
#
# **3.** Kane, F. (2017). Hands-On Data Science and Python Machine Learning. Packt Publishing. (pp. 56-62).
#
# **4.** Subramanian, G. (2015). Python Data Science Cookbook. Packt Publishing. (pp. 65-74).
